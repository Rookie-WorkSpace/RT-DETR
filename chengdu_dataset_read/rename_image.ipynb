# %% [markdown]
# # 重命名座椅数据集图片名称

# %%
import warnings
import PIL
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.patheffects as pe
import os
import random
from PIL import Image

warnings.filterwarnings('ignore')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
def rename_image(image_dir, annotation_file):
    """
    重命名图片文件
    """
    import json
    import shutil
    
    new_image_dir = os.path.join(os.path.dirname(image_dir), os.path.basename(image_dir) + '_rename')

    os.makedirs(new_image_dir, exist_ok=True)
    with open(annotation_file, 'r') as f:
        annotations = json.load(f)
    for i, image in enumerate(annotations['images']):
        print(f"{i:06d}", image['file_name'])
        file_name = image['file_name']
        new_name = f"{i:06d}.jpg"
        old_path = os.path.join(image_dir, file_name)
        new_path = os.path.join(new_image_dir, new_name)
        shutil.copy(old_path, new_path)
        annotations['images'][i]['file_name'] = new_name
    with open(os.path.join(new_image_dir, '_annotations.coco.json'), 'w') as f:
        json.dump(annotations, f)

# %%
image_dir = r"\\?\C:\Users\Rooki\Desktop\AI\CV\RT-DETR\chengdu_dataset\train"
# 读取COCO格式的标注文件
annotation_file = r"\\?\C:\Users\Rooki\Desktop\AI\CV\RT-DETR\chengdu_dataset\train\_annotations.coco.json"

rename_image(image_dir, annotation_file)
# Out:
# 000000 1744654551214_2d20cbda-dc0a-47a5-a7fc-ec59969b5627__p_0040_d75a83877b4645c6a5b34e993f021e59_6154901fb0bc4ee2b3_1744655549846.jpg
# 000001 1744654551214_2d20cbda-dc0a-47a5-a7fc-ec59969b5627__p_0040_d75a83877b4645c6a5b34e993f021e59_6154901fb0bc4ee2b3.jpg
# 000002 1744654551171_15a8e727-b9a5-4f85-8511-7ac32dfcefc8__p_0038_76aaf76c6231497e9a89580f69bea22b_cf48045bb804414589_1744655548542.jpg
# 000003 1744654551171_15a8e727-b9a5-4f85-8511-7ac32dfcefc8__p_0038_76aaf76c6231497e9a89580f69bea22b_cf48045bb804414589.jpg
# 000004 1744654551106_2f46f35b-e92b-478a-b565-02c45147a622__p_00381_76aaf76c6231497e9a89580f69bea22b_7994f54fb6a74e9484_1744655547319.jpg
# 000005 1744654551106_2f46f35b-e92b-478a-b565-02c45147a622__p_00381_76aaf76c6231497e9a89580f69bea22b_7994f54fb6a74e9484.jpg
# 000006 1744654551157_30445555-e1ec-4ee3-8ab3-131520a0c2c7__p_0038_76aaf76c6231497e9a89580f69bea22b_97c99fe4-083d-472e-8d40-3a5771e928b4_1744655547842.jpg
# ...

# %%
image_dir = r"\\?\C:\Users\Rooki\Desktop\AI\CV\RT-DETR\chengdu_dataset\valid"
# 读取COCO格式的标注文件
annotation_file = r"\\?\C:\Users\Rooki\Desktop\AI\CV\RT-DETR\chengdu_dataset\valid\_annotations.coco.json"

rename_image(image_dir, annotation_file)
# Out:
# 000000 1744649605925_5f4dfce7e17a47b5_41f51fcfd7c1c960e4f425e1cba2bb0332343ced_原图.jpg
# 000001 1744649605941_eba9252dfbef4fb8_42bae3e698dfa3c746e1b894fba3ad2ef1c07276_原图.jpg
# 000002 1744649605955__p_0049_a7c327e9827c4d278e19a64071c755ec_d608bbfb-7624-4873-af0d-ba0d42e1972d.jpg
# 000003 1744649605973__p_0020_3440881434c44c34b03aaff0b5253d5e_1524c33f-bea1-4e6e-b467-e205a294a40e.jpg
# 000004 1744649605991__p_0064_6f565be5150d4b9eb06d0ed908431ae1_9b005a50-782d-49ea-9a20-d97084840c53.jpg
# 000005 1744649605036_3c6d565ff4224c45_e45120dc2d0a08e00682ac0d349e0f9d3d30aecb.jpg
# 000006 1744649605058__p_0008_cb4d92b726984a20ab11673eed16716c_120b04de-7897-474a-bbfa-44340727b2da.jpg
# 000007 1744649605076__p_0031_4e002985ef7c4913a4524f7f80d71f1c_0acd1681-2b5e-4798-b120-dfb589a98c71.jpg
# 000008 1744649605090__p_0038_76aaf76c6231497e9a89580f69bea22b_e6a89ff3-eba2-461b-91e2-b589211529e4.jpg
# 000009 1744649605106__p_0031_4e002985ef7c4913a4524f7f80d71f1c_cdca8b91-23ce-4a63-8d5f-c50d2962d40e.jpg
# ...
